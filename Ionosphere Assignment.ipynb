# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
np.__version__
# Out:
# '1.19.2'

# %%
# Load the dataset.
df = pd.read_csv('data.csv', delimiter=',')

# %%
# Find the shape of the dataset 
df.shape
# Out:
# (351, 35)

# %%
df.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# 0    0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
# 1   -0.19040   -0.11593   -0.16626   -0.06288   -0.13738   -0.02447      b
# 2    0.43100   -0.17365    0.60436   -0.24180    0.56045   -0.38238      g
# 3    1.00000   -0.20099    0.25682    1.00000   -0.32382    1.00000      b
# 4    0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df.describe().T
# Out:
#            count      mean       std  min       25%      50%       75%  max
# feature1   351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# feature2   351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# feature3   351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# feature4   351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# feature5   351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# feature6   351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# feature7   351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# feature8   351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# feature9   351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# feature10  351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# feature11  351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# feature12  351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# feature13  351.0  0.400801  0.622186 -1.0  0.000000  0.64407  0.955505  1.0
# feature14  351.0  0.093414  0.494873 -1.0 -0.073725  0.03027  0.374860  1.0
# feature15  351.0  0.344159  0.652828 -1.0  0.000000  0.60194  0.919330  1.0
# feature16  351.0  0.071132  0.458371 -1.0 -0.081705  0.00000  0.308975  1.0
# feature17  351.0  0.381949  0.618020 -1.0  0.000000  0.59091  0.935705  1.0
# feature18  351.0 -0.003617  0.496762 -1.0 -0.225690  0.00000  0.195285  1.0
# feature19  351.0  0.359390  0.626267 -1.0  0.000000  0.57619  0.899265  1.0
# feature20  351.0 -0.024025  0.519076 -1.0 -0.234670  0.00000  0.134370  1.0
# feature21  351.0  0.336695  0.609828 -1.0  0.000000  0.49909  0.894865  1.0
# feature22  351.0  0.008296  0.518166 -1.0 -0.243870  0.00000  0.188760  1.0
# feature23  351.0  0.362475  0.603767 -1.0  0.000000  0.53176  0.911235  1.0
# feature24  351.0 -0.057406  0.527456 -1.0 -0.366885  0.00000  0.164630  1.0
# feature25  351.0  0.396135  0.578451 -1.0  0.000000  0.55389  0.905240  1.0
# feature26  351.0 -0.071187  0.508495 -1.0 -0.332390 -0.01505  0.156765  1.0
# feature27  351.0  0.541641  0.516205 -1.0  0.286435  0.70824  0.999945  1.0
# feature28  351.0 -0.069538  0.550025 -1.0 -0.443165 -0.01769  0.153535  1.0
# feature29  351.0  0.378445  0.575886 -1.0  0.000000  0.49664  0.883465  1.0
# feature30  351.0 -0.027907  0.507974 -1.0 -0.236885  0.00000  0.154075  1.0
# feature31  351.0  0.352514  0.571483 -1.0  0.000000  0.44277  0.857620  1.0
# feature32  351.0 -0.003794  0.513574 -1.0 -0.242595  0.00000  0.200120  1.0
# feature33  351.0  0.349364  0.522663 -1.0  0.000000  0.40956  0.813765  1.0
# feature34  351.0  0.014480  0.468337 -1.0 -0.165350  0.00000  0.171660  1.0

# %%
for feature in df:
    print(feature)
    print(len(df[feature].unique()))
# Out:
# feature1
# 2
# feature2
# 1
# feature3
# 219
# feature4
# 269
# feature5
# 204
# feature6
# 259
# feature7
# 231
# feature8
# 260
# feature9
# 244
# feature10
# 267
# feature11
# 246
# feature12
# 269
# feature13
# 238
# feature14
# 266
# feature15
# 234
# feature16
# 270
# feature17
# 254
# feature18
# 280
# feature19
# 254
# feature20
# 266
# feature21
# 248
# feature22
# 265
# feature23
# 248
# feature24
# 264
# feature25
# 256
# feature26
# 273
# feature27
# 256
# feature28
# 281
# feature29
# 244
# feature30
# 266
# feature31
# 243
# feature32
# 263
# feature33
# 245
# feature34
# 263
# label
# 2

# %%
df['feature2'].unique()
# Out:
# array([0], dtype=int64)

# %%
df.drop(df.columns[1], inplace=True, axis=1)

# %%
df.head()
# Out:
#    feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 0         1   0.99539  -0.05889   0.85243   0.02306   0.83398  -0.37708
# 1         1   1.00000  -0.18829   0.93035  -0.36156  -0.10868  -0.93597
# 2         1   1.00000  -0.03365   1.00000   0.00485   1.00000  -0.12062
# 3         1   1.00000  -0.45161   1.00000   1.00000   0.71216  -1.00000
# 4         1   1.00000  -0.02401   0.94140   0.06531   0.92106  -0.23255
#
#    feature9  feature10  feature11  ...  feature26  feature27  feature28  \
# 0   1.00000    0.03760    0.85243  ...   -0.51171    0.41078   -0.46168
# 1   1.00000   -0.04549    0.50874  ...   -0.26569   -0.20468   -0.18401
# 2   0.88965    0.01198    0.73082  ...   -0.40220    0.58984   -0.22145
# 3   0.00000    0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4   0.77152   -0.16399    0.52798  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# 0    0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
# 1   -0.19040   -0.11593   -0.16626   -0.06288   -0.13738   -0.02447      b
# 2    0.43100   -0.17365    0.60436   -0.24180    0.56045   -0.38238      g
# 3    1.00000   -0.20099    0.25682    1.00000   -0.32382    1.00000      b
# 4    0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
#
# [5 rows x 34 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature3   351 non-null    float64
#  2   feature4   351 non-null    float64
#  3   feature5   351 non-null    float64
#  4   feature6   351 non-null    float64
#  5   feature7   351 non-null    float64
#  6   feature8   351 non-null    float64
#  7   feature9   351 non-null    float64
#  8   feature10  351 non-null    float64
#  9   feature11  351 non-null    float64
#  10  feature12  351 non-null    float64
#  11  feature13  351 non-null    float64
#  12  feature14  351 non-null    float64
#  13  feature15  351 non-null    float64
#  14  feature16  351 non-null    float64
#  15  feature17  351 non-null    float64
#  16  feature18  351 non-null    float64
#  17  feature19  351 non-null    float64
#  18  feature20  351 non-null    float64
#  19  feature21  351 non-null    float64
#  20  feature22  351 non-null    float64
#  21  feature23  351 non-null    float64
#  22  feature24  351 non-null    float64
#  23  feature25  351 non-null    float64
#  24  feature26  351 non-null    float64
#  25  feature27  351 non-null    float64
#  26  feature28  351 non-null    float64
#  27  feature29  351 non-null    float64
#  28  feature30  351 non-null    float64
#  29  feature31  351 non-null    float64
#  30  feature32  351 non-null    float64
#  31  feature33  351 non-null    float64
#  32  feature34  351 non-null    float64
#  33  label      351 non-null    object
# dtypes: float64(32), int64(1), object(1)
# memory usage: 93.4+ KB

# %%
'''for feature in df:
    print(feature)
    df[feature].hist()
    plt.show()'''

# df.hist()
# plt.show()
# Out:
# 'for feature in df:\n    print(feature)\n    df[feature].hist()\n    plt.show()'

# %%
# Check summary statistics
df.describe()
# Out:
#          feature1    feature3    feature4    feature5    feature6    feature7  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.891738    0.641342    0.044372    0.601068    0.115889    0.550095
# std      0.311155    0.497708    0.441435    0.519862    0.460810    0.492654
# min      0.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.472135   -0.064735    0.412660   -0.024795    0.211310
# 50%      1.000000    0.871110    0.016310    0.809200    0.022800    0.728730
# 75%      1.000000    1.000000    0.194185    1.000000    0.334655    0.969240
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          feature8    feature9   feature10   feature11  ...   feature25  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.119360    0.511848    0.181345    0.476183  ...    0.396135
# std      0.520750    0.507066    0.483851    0.563496  ...    0.578451
# min     -1.000000   -1.000000   -1.000000   -1.000000  ...   -1.000000
# 25%     -0.054840    0.087110   -0.048075    0.021120  ...    0.000000
# 50%      0.014710    0.684210    0.018290    0.667980  ...    0.553890
# 75%      0.445675    0.953240    0.534195    0.957895  ...    0.905240
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#         feature26   feature27   feature28   feature29   feature30   feature31  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean    -0.071187    0.541641   -0.069538    0.378445   -0.027907    0.352514
# std      0.508495    0.516205    0.550025    0.575886    0.507974    0.571483
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%     -0.332390    0.286435   -0.443165    0.000000   -0.236885    0.000000
# 50%     -0.015050    0.708240   -0.017690    0.496640    0.000000    0.442770
# 75%      0.156765    0.999945    0.153535    0.883465    0.154075    0.857620
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         feature32   feature33   feature34
# count  351.000000  351.000000  351.000000
# mean    -0.003794    0.349364    0.014480
# std      0.513574    0.522663    0.468337
# min     -1.000000   -1.000000   -1.000000
# 25%     -0.242595    0.000000   -0.165350
# 50%      0.000000    0.409560    0.000000
# 75%      0.200120    0.813765    0.171660
# max      1.000000    1.000000    1.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.

# %%
# Find missing values
df.isnull().sum()
# Out:
# feature1     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
df['label'] = [1 if lbl == 'g' else 0 for lbl in df['label']]

# %%
train_data = df.sample(frac= 0.6, random_state=125)
test_data = df.drop(train_data.index)

# %%
train_label = train_data.iloc[:,-1]
train_data = train_data.iloc[:,0:-1]
test_label = test_data.iloc[:,-1]
test_data = test_data.iloc[:,0:-1]

# %%
# df.drop(columns= 'label', inplace = True)

# %%
train_data.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 270         1   1.00000   0.08013   0.96775  -0.00482   0.96683  -0.00722
# 116         1   1.00000  -0.14754   1.00000   0.04918   0.57377  -0.01639
# 135         1   0.89706   0.38235   0.91176   0.37500   0.74265   0.67647
# 91          1   0.84557  -0.08580  -0.31745  -0.80553  -0.08961  -0.56435
# 100         1   1.00000  -1.00000   0.00000   0.00000   0.77941  -0.99265
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 270   0.87980   -0.03923    1.00000  ...    0.98164    0.02003    0.93772
# 116   0.65574    0.01639    0.85246  ...    0.31148   -0.34426    0.52385
# 135   0.45588    0.77941    0.19118  ...   -0.74265   -0.12500   -0.67925
# 91    0.80648    0.04576    0.89514  ...    0.78932   -0.03718    0.70882
# 100   0.80882    0.55147   -0.41912  ...   -1.00000   -1.00000   -1.00000
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 270   -0.03034    1.00000   -0.05843    0.92774   -0.03464    0.92226
# 116   -0.20325    0.32787   -0.03279    0.27869   -0.44262    0.49180
# 135   -0.24131   -0.55147   -0.42647   -0.44118   -0.50735   -0.28676
# 91    -0.25288    0.77884   -0.14109   -0.21354   -0.78170   -0.18494
# 100   -1.00000    1.00000   -1.00000    1.00000   -1.00000    0.00000
#
#      feature34
# 270   -0.03673
# 116   -0.06557
# 135   -0.56618
# 91    -0.59867
# 100    0.00000
#
# [5 rows x 33 columns]

# %%
train_label
# Out:
# 270    1
# 116    0
# 135    1
# 91     0
# 100    0
#       ..
# 213    1
# 161    1
# 141    1
# 59     0
# 113    1
# Name: label, Length: 211, dtype: int64

# %% [markdown]
# - Standardized the Input Variables. **Hint**: Centeralized the data

# %%
train_data.shape
# Out:
# (211, 33)

# %%
test_data.shape
# Out:
# (140, 33)

# %%
train_label.shape
# Out:
# (211,)

# %%
test_label.shape
# Out:
# (140,)

# %%
train_label.sum()
# Out:
# 140

# %%
len(train_label)
# Out:
# 211

# %%
# train_label.sum()/len(train_label)

# %% [markdown]
# ### Data Preprocessing

# %%
train_data = train_data.to_numpy()

# %%
train_label = train_label.to_numpy().astype('float32')

# %%
test_data = test_data.to_numpy()

# %%
test_label = test_label.to_numpy().astype('float32')

# %%
print(type(train_data))
print(type(train_label))
print(type(test_data))
print(type(test_label))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(train_data.dtype)
print(train_label.dtype)
print(test_label.dtype)
print(test_data.dtype)
# Out:
# float64
# float32
# float32
# float64

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# - Model : 1 hidden layers including 16 unit.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1,  activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               4352
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 12,673
# Trainable params: 12,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

model.compile(optimizer = 'RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_label, validation_split=0.25, epochs= 75, batch_size = 32)
# Out:
# Epoch 1/75
# 5/5 [==============================] - 3s 130ms/step - loss: 0.6251 - accuracy: 0.6986 - val_loss: 0.5465 - val_accuracy: 0.8113
# Epoch 2/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5406 - accuracy: 0.7583 - val_loss: 0.4925 - val_accuracy: 0.8113
# Epoch 3/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4762 - accuracy: 0.8014 - val_loss: 0.4442 - val_accuracy: 0.8491
# Epoch 4/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4367 - accuracy: 0.8118 - val_loss: 0.4097 - val_accuracy: 0.8868
# Epoch 5/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4025 - accuracy: 0.8964 - val_loss: 0.3793 - val_accuracy: 0.9057
# Epoch 6/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3559 - accuracy: 0.8977 - val_loss: 0.3434 - val_accuracy: 0.9057
# Epoch 7/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3132 - accuracy: 0.9127 - val_loss: 0.3209 - val_accuracy: 0.9245
# Epoch 8/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2826 - accuracy: 0.9154 - val_loss: 0.2985 - val_accuracy: 0.9245
# Epoch 9/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2708 - accuracy: 0.9311 - val_loss: 0.2793 - val_accuracy: 0.9245
# Epoch 10/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2896 - accuracy: 0.9272 - val_loss: 0.2675 - val_accuracy: 0.9245
# Epoch 11/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2307 - accuracy: 0.9476 - val_loss: 0.2519 - val_accuracy: 0.9434
# Epoch 12/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2127 - accuracy: 0.9311 - val_loss: 0.2388 - val_accuracy: 0.9623
# Epoch 13/75
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1792 - accuracy: 0.9563 - val_loss: 0.2304 - val_accuracy: 0.9623
# Epoch 14/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1774 - accuracy: 0.9614 - val_loss: 0.2212 - val_accuracy: 0.9623
# Epoch 15/75
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1835 - accuracy: 0.9199 - val_loss: 0.2128 - val_accuracy: 0.9623
# Epoch 16/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1770 - accuracy: 0.9376 - val_loss: 0.2108 - val_accuracy: 0.9623
# Epoch 17/75
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1778 - accuracy: 0.9420 - val_loss: 0.2052 - val_accuracy: 0.9623
# Epoch 18/75
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1571 - accuracy: 0.9566 - val_loss: 0.2009 - val_accuracy: 0.9623
# Epoch 19/75
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1578 - accuracy: 0.9221 - val_loss: 0.1978 - val_accuracy: 0.9623
# Epoch 20/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1090 - accuracy: 0.9796 - val_loss: 0.1931 - val_accuracy: 0.9623
# Epoch 21/75
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1255 - accuracy: 0.9647 - val_loss: 0.1934 - val_accuracy: 0.9623
# Epoch 22/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1175 - accuracy: 0.9700 - val_loss: 0.1889 - val_accuracy: 0.9434
# Epoch 23/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1277 - accuracy: 0.9436 - val_loss: 0.1856 - val_accuracy: 0.9623
# Epoch 24/75
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1051 - accuracy: 0.9838 - val_loss: 0.1911 - val_accuracy: 0.9623
# Epoch 25/75
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1075 - accuracy: 0.9746 - val_loss: 0.1891 - val_accuracy: 0.9623
# Epoch 26/75
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1303 - accuracy: 0.9514 - val_loss: 0.1903 - val_accuracy: 0.9623
# Epoch 27/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1178 - accuracy: 0.9483 - val_loss: 0.1991 - val_accuracy: 0.9623
# Epoch 28/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0919 - accuracy: 0.9725 - val_loss: 0.1848 - val_accuracy: 0.9434
# Epoch 29/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0935 - accuracy: 0.9747 - val_loss: 0.1828 - val_accuracy: 0.9434
# Epoch 30/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1228 - accuracy: 0.9642 - val_loss: 0.1854 - val_accuracy: 0.9623
# Epoch 31/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0992 - accuracy: 0.9793 - val_loss: 0.1890 - val_accuracy: 0.9623
# Epoch 32/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0657 - accuracy: 0.9720 - val_loss: 0.1835 - val_accuracy: 0.9434
# Epoch 33/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0814 - accuracy: 0.9689 - val_loss: 0.1916 - val_accuracy: 0.9623
# Epoch 34/75
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0716 - accuracy: 0.9854 - val_loss: 0.1933 - val_accuracy: 0.9434
# Epoch 35/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0678 - accuracy: 0.9850 - val_loss: 0.1870 - val_accuracy: 0.9623
# Epoch 36/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0705 - accuracy: 0.9871 - val_loss: 0.1836 - val_accuracy: 0.9623
# Epoch 37/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0674 - accuracy: 0.9880 - val_loss: 0.1774 - val_accuracy: 0.9434
# Epoch 38/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0617 - accuracy: 0.9845 - val_loss: 0.1812 - val_accuracy: 0.9623
# Epoch 39/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0559 - accuracy: 0.9816 - val_loss: 0.1759 - val_accuracy: 0.9434
# Epoch 40/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0614 - accuracy: 0.9798 - val_loss: 0.1843 - val_accuracy: 0.9434
# Epoch 41/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0430 - accuracy: 0.9966 - val_loss: 0.1797 - val_accuracy: 0.9623
# Epoch 42/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0894 - accuracy: 0.9785 - val_loss: 0.1898 - val_accuracy: 0.9623
# Epoch 43/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0623 - accuracy: 0.9901 - val_loss: 0.1908 - val_accuracy: 0.9623
# Epoch 44/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0467 - accuracy: 0.9901 - val_loss: 0.1896 - val_accuracy: 0.9434
# Epoch 45/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0876 - accuracy: 0.9751 - val_loss: 0.1908 - val_accuracy: 0.9434
# Epoch 46/75
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0487 - accuracy: 0.9867 - val_loss: 0.1878 - val_accuracy: 0.9434
# Epoch 47/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0516 - accuracy: 0.9922 - val_loss: 0.1903 - val_accuracy: 0.9434
# Epoch 48/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0468 - accuracy: 0.9949 - val_loss: 0.1897 - val_accuracy: 0.9623
# Epoch 49/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0450 - accuracy: 0.9914 - val_loss: 0.1934 - val_accuracy: 0.9623
# Epoch 50/75
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0323 - accuracy: 0.9979 - val_loss: 0.1793 - val_accuracy: 0.9434
# Epoch 51/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0731 - accuracy: 0.9772 - val_loss: 0.1831 - val_accuracy: 0.9434
# Epoch 52/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0358 - accuracy: 0.9828 - val_loss: 0.1917 - val_accuracy: 0.9434
# Epoch 53/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9623
# Epoch 54/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0423 - accuracy: 0.9741 - val_loss: 0.2124 - val_accuracy: 0.9623
# Epoch 55/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0419 - accuracy: 0.9793 - val_loss: 0.2059 - val_accuracy: 0.9623
# Epoch 56/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0148 - accuracy: 0.9979 - val_loss: 0.2026 - val_accuracy: 0.9623
# Epoch 57/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9623
# Epoch 58/75
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0322 - accuracy: 0.9966 - val_loss: 0.2029 - val_accuracy: 0.9434
# Epoch 59/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0253 - accuracy: 0.9932 - val_loss: 0.2065 - val_accuracy: 0.9434
# Epoch 60/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9434
# Epoch 61/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.9623
# Epoch 62/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0304 - accuracy: 0.9837 - val_loss: 0.2104 - val_accuracy: 0.9434
# Epoch 63/75
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9623
# Epoch 64/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0197 - accuracy: 0.9966 - val_loss: 0.2137 - val_accuracy: 0.9434
# Epoch 65/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0335 - accuracy: 0.9849 - val_loss: 0.2071 - val_accuracy: 0.9434
# Epoch 66/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9434
# Epoch 67/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9434
# Epoch 68/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.2163 - val_accuracy: 0.9623
# Epoch 69/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9434
# Epoch 70/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0359 - accuracy: 0.9870 - val_loss: 0.2197 - val_accuracy: 0.9623
# Epoch 71/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0225 - accuracy: 0.9949 - val_loss: 0.2172 - val_accuracy: 0.9623
# Epoch 72/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.2294 - val_accuracy: 0.9623
# Epoch 73/75
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9623
# Epoch 74/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2373 - val_accuracy: 0.9623
# Epoch 75/75
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9623

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(75)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
score = model.evaluate(test_data, test_label)
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2764 - accuracy: 0.9286

# %%
score
# Out:
# [0.2764213979244232, 0.9285714030265808]

# %%
predictions=model.predict(test_data)

# %%
y_pred = (predictions > 0.5)

# %%
tf.math.confusion_matrix(
    test_label, y_pred, num_classes=2, weights=None, dtype=tf.dtypes.int32,
    name=None
)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[47,  8],
#        [ 2, 83]])>

# %%
np.count_nonzero(y_pred)
# Out:
# 91
